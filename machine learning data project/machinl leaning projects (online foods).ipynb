# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\\dell\\OneDrive\\Desktop\\onlinefoods.csv")

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
df1 = df.copy()
df1
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.shape
# Out:
# (388, 13)

# %%
columns = df[['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
       'Educational Qualifications', 'Family size', 'Output', 'Feedback', 'Unnamed: 12']]

plt.figure(figsize = (22, 25))
for i, col in enumerate(columns):
    plt.subplot(7, 2, i+1) #subplot(row of graphs, column of graphs, increment)
    counts = df[col].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                     int64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 12                    object
# dtype: object

# %%
sns.pairplot(df,hue = "Feedback")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender',data=df)
plt.title('Count of Gender ')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),vmin=-1,vmax=1,annot=True)
# Out:
# <Axes: >

# %%
x = df1.iloc[:,1:11].values
x
# Out:
# array([['Female', 'Single', 'Student', ..., 77.5993, 560001, 'Yes'],
#        ['Female', 'Single', 'Student', ..., 77.5773, 560009, 'Yes'],
#        ['Male', 'Single', 'Student', ..., 77.6593, 560017, 'Yes'],
#        ...,
#        ['Female', 'Single', 'Student', ..., 77.5533, 560010, 'Yes'],
#        ['Male', 'Single', 'Student', ..., 77.5773, 560009, 'Yes'],
#        ['Male', 'Single', 'Student', ..., 77.5764, 560078, 'Yes']],
#       dtype=object)

# %%
y = df1.iloc[:,-1].values
y
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No',
# ...

# %%
dfpred = pd.DataFrame({'Actual Data':ytest})
dfpred
# Out:
#    Actual Data
# 0          Yes
# 1           No
# 2           No
# 3          Yes
# 4          Yes
# ..         ...
# 73          No
# 74          No
# 75          No
# 76         Yes
# 77         Yes
#
# [78 rows x 1 columns]

# %%
X=df.drop(columns = "Feedback", axis = 1)
y=df[["Feedback"]]
df2=pd.DataFrame(X)
print(df2.to_string())
# Out:
#      Age  Gender     Marital Status      Occupation   Monthly Income Educational Qualifications  Family size  latitude  longitude  Pin code Output Unnamed: 12
# 0     20  Female             Single         Student        No Income              Post Graduate            4   12.9766    77.5993    560001    Yes         Yes
# 1     24  Female             Single         Student   Below Rs.10000                   Graduate            3   12.9770    77.5773    560009    Yes         Yes
# 2     22    Male             Single         Student   Below Rs.10000              Post Graduate            3   12.9551    77.6593    560017    Yes         Yes
# 3     22  Female             Single         Student        No Income                   Graduate            6   12.9473    77.5616    560019    Yes         Yes
# 4     22    Male             Single         Student   Below Rs.10000              Post Graduate            4   12.9850    77.5533    560010    Yes         Yes
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(X,y, test_size= .25, random_state=0)

# %%
print("x_train b4 scaling..")
df3=pd.DataFrame(x_train)
print(df3.to_string())
# Out:
# x_train b4 scaling..
#      Age  Gender     Marital Status      Occupation   Monthly Income Educational Qualifications  Family size  latitude  longitude  Pin code Output Unnamed: 12
# 21    22    Male             Single         Student        No Income              Post Graduate            4   13.0298    77.6047    560032    Yes         Yes
# 300   22    Male             Single         Student   Below Rs.10000              Post Graduate            3   12.9551    77.6593    560017    Yes         Yes
# 181   23    Male             Single         Student   Below Rs.10000                   Graduate            3   12.8652    77.5240    560109    Yes         Yes
# 200   23    Male             Single         Student        No Income              Post Graduate            2   12.9261    77.6221    560034    Yes         Yes
# 49    22  Female             Single         Student   10001 to 25000              Post Graduate            5   12.9850    77.5533    560010    Yes         Yes
# ...

# %%
y_pred= (x_test)
print(y_pred)
# Out:
#      Age  Gender     Marital Status      Occupation   Monthly Income  \
# 54    22    Male             Single         Student        No Income
# 124   24    Male            Married  Self Employeed  More than 50000
# 263   23  Female  Prefer not to say        Employee   10001 to 25000
# 175   23  Female             Single        Employee   10001 to 25000
# 282   23    Male             Single         Student        No Income
# ..   ...     ...                ...             ...              ...
# 365   22    Male             Single         Student        No Income
# 239   23  Female             Single         Student        No Income
# 380   27  Female            Married        Employee  More than 50000
# 89    28    Male            Married  Self Employeed   10001 to 25000
# 167   24  Female             Single         Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# ...

# %%
y_pred=(x_test)
print("------------PREDICTION----------")
df2=({"Actual Result-y":y_test,"Prediction Result":y_pred})
# Out:
# ------------PREDICTION----------

# %%
dfpred = ({'Actual Data':y_test, 'Predicted Data':y_pred})
dfpred
# Out:
# {'Actual Data':       Feedback
#  54    Positive
#  124  Negative
#  263  Negative
#  175   Positive
#  282   Positive
#  ..         ...
#  365   Positive
#  239   Positive
#  380   Positive
#  89   Negative
#  167   Positive
#
#  [97 rows x 1 columns],
#  'Predicted Data':      Age  Gender     Marital Status      Occupation   Monthly Income  \
#  54    22    Male             Single         Student        No Income
#  124   24    Male            Married  Self Employeed  More than 50000
#  263   23  Female  Prefer not to say        Employee   10001 to 25000
#  175   23  Female             Single        Employee   10001 to 25000
#  282   23    Male             Single         Student        No Income
#  ..   ...     ...                ...             ...              ...
#  365   22    Male             Single         Student        No Income
#  239   23  Female             Single         Student        No Income
#  380   27  Female            Married        Employee  More than 50000
# ...

# %%
df1
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
x,y
# Out:
# (array([['Female', 'Single', 'Student', ..., 77.5993, 560001, 'Yes'],
#         ['Female', 'Single', 'Student', ..., 77.5773, 560009, 'Yes'],
#         ['Male', 'Single', 'Student', ..., 77.6593, 560017, 'Yes'],
#         ...,
#         ['Female', 'Single', 'Student', ..., 77.5533, 560010, 'Yes'],
#         ['Male', 'Single', 'Student', ..., 77.5773, 560009, 'Yes'],
#         ['Male', 'Single', 'Student', ..., 77.5764, 560078, 'Yes']],
#        dtype=object),
#        Feedback
#  0     Positive
#  1     Positive
#  2    Negative
#  3     Positive
#  4     Positive
#  ..         ...
#  383   Positive
#  384   Positive
#  385   Positive
#  386   Positive
#  387   Positive
#
#  [388 rows x 1 columns])

# %%
from sklearn.model_selection import train_test_split 
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state =0)
